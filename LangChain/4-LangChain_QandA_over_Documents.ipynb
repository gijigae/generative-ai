# %% [markdown]
# # LangChain: Q&A over Documents
#
# An example might be a tool that would allow you to query a product catalog for items of interest.
#
# First install necessary libraries and import them.

# %%
# Install Vertex AI LLM SDK
import sys
# !{sys.executable} -m pip install google-cloud-aiplatform langchain pandas datasets google-api-python-client chromadb pypdf faiss-cpu transformers config --upgrade --user
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /home/jupyter/.local/lib/python3.9/site-packages (1.26.0)
# Requirement already satisfied: langchain in /home/jupyter/.local/lib/python3.9/site-packages (0.0.206)
# Collecting langchain
#   Downloading langchain-0.0.207-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: pandas in /home/jupyter/.local/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: datasets in /home/jupyter/.local/lib/python3.9/site-packages (2.13.0)
# Requirement already satisfied: google-api-python-client in /home/jupyter/.local/lib/python3.9/site-packages (2.89.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.90.0-py2.py3-none-any.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 35.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: chromadb in /home/jupyter/.local/lib/python3.9/site-packages (0.3.26)
# Requirement already satisfied: pypdf in /home/jupyter/.local/lib/python3.9/site-packages (3.10.0)
# Requirement already satisfied: faiss-cpu in /home/jupyter/.local/lib/python3.9/site-packages (1.7.4)
# Requirement already satisfied: transformers in /home/jupyter/.local/lib/python3.9/site-packages (4.30.2)
# Requirement already satisfied: config in /home/jupyter/.local/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-aiplatform) (2.11.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-aiplatform) (1.22.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-aiplatform) (4.23.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/envs/python39/lib/python3.9/site-packages (from google-cloud-aiplatform) (23.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-aiplatform) (2.9.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-aiplatform) (3.11.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-aiplatform) (1.10.1)
# Requirement already satisfied: shapely<2.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-aiplatform) (1.8.5.post1)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (2.0.16)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (0.5.8)
# Requirement already satisfied: langchainplus-sdk>=0.0.13 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (0.0.16)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (1.25.0)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (1.10.9)
# Requirement already satisfied: requests<3,>=2 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/python39/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter/.local/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/jupyter/.local/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from datasets) (12.0.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/jupyter/.local/lib/python3.9/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: tqdm>=4.62.1 in /home/jupyter/.local/lib/python3.9/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /home/jupyter/.local/lib/python3.9/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /home/jupyter/.local/lib/python3.9/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/jupyter/.local/lib/python3.9/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /home/jupyter/.local/lib/python3.9/site-packages (from datasets) (0.15.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-api-python-client) (2.20.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/jupyter/.local/lib/python3.9/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: hnswlib>=0.7 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (0.7.0)
# Requirement already satisfied: clickhouse-connect>=0.5.7 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (0.6.3)
# Requirement already satisfied: duckdb>=0.7.1 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (0.8.1)
# Requirement already satisfied: fastapi>=0.85.1 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (0.97.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: posthog>=2.4.0 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/envs/python39/lib/python3.9/site-packages (from chromadb) (4.6.3)
# Requirement already satisfied: pulsar-client>=3.1.0 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (3.2.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (1.15.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (0.13.3)
# Requirement already satisfied: overrides>=7.3.1 in /home/jupyter/.local/lib/python3.9/site-packages (from chromadb) (7.3.1)
# Requirement already satisfied: filelock in /home/jupyter/.local/lib/python3.9/site-packages (from transformers) (3.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/jupyter/.local/lib/python3.9/site-packages (from transformers) (2023.6.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/jupyter/.local/lib/python3.9/site-packages (from transformers) (0.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: certifi in /home/jupyter/.local/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2023.5.7)
# Requirement already satisfied: urllib3>=1.26 in /home/jupyter/.local/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (1.26.16)
# Requirement already satisfied: zstandard in /home/jupyter/.local/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (0.21.0)
# Requirement already satisfied: lz4 in /home/jupyter/.local/lib/python3.9/site-packages (from clickhouse-connect>=0.5.7->chromadb) (4.3.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /home/jupyter/.local/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /home/jupyter/.local/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /home/jupyter/.local/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/jupyter/.local/lib/python3.9/site-packages (from fastapi>=0.85.1->chromadb) (0.27.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/jupyter/.local/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.59.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /home/jupyter/.local/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.54.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /home/jupyter/.local/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.54.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jupyter/.local/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jupyter/.local/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/python39/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.5.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /home/jupyter/.local/lib/python3.9/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/jupyter/.local/lib/python3.9/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: coloredlogs in /home/jupyter/.local/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/jupyter/.local/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: sympy in /home/jupyter/.local/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: monotonic>=1.5 in /home/jupyter/.local/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/jupyter/.local/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyter/.local/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/jupyter/.local/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: click>=7.0 in /home/jupyter/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /home/jupyter/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/jupyter/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.5.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/jupyter/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/jupyter/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/jupyter/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: websockets>=10.4 in /home/jupyter/.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/jupyter/.local/lib/python3.9/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/jupyter/.local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/jupyter/.local/lib/python3.9/site-packages (from starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb) (3.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/jupyter/.local/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/jupyter/.local/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /home/jupyter/.local/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/jupyter/.local/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home/jupyter/.local/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi>=0.85.1->chromadb) (1.1.1)
# Installing collected packages: langchain, google-api-python-client
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.0.206
#     Uninstalling langchain-0.0.206:
#       Successfully uninstalled langchain-0.0.206
#   WARNING: The script langchain-server is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.89.0
#     Uninstalling google-api-python-client-2.89.0:
#       Successfully uninstalled google-api-python-client-2.89.0
# Successfully installed google-api-python-client-2.90.0 langchain-0.0.207

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatVertexAI
from langchain.document_loaders import CSVLoader
from langchain.vectorstores import DocArrayInMemorySearch
from langchain.embeddings import VertexAIEmbeddings
from IPython.display import display, Markdown

# %%
from langchain.indexes import VectorstoreIndexCreator

# %%
import sys
# !{sys.executable} -m pip install "langchain[docarray]"
# Out:
# Requirement already satisfied: langchain[docarray] in /home/jupyter/.local/lib/python3.9/site-packages (0.0.207)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (2.0.16)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (0.5.8)
# Requirement already satisfied: langchainplus-sdk>=0.0.13 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (0.0.16)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (1.25.0)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (1.10.9)
# Requirement already satisfied: requests<3,>=2 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/jupyter/.local/lib/python3.9/site-packages (from langchain[docarray]) (8.2.2)
# Collecting docarray[hnswlib]<0.33.0,>=0.32.0 (from langchain[docarray])
#   Downloading docarray-0.32.1-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jupyter/.local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain[docarray]) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /home/jupyter/.local/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /home/jupyter/.local/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /home/jupyter/.local/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (0.9.0)
# Collecting orjson>=3.8.2 (from docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray])
#   Downloading orjson-3.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.9/136.9 kB 19.7 MB/s eta 0:00:00
# Collecting rich>=13.1.0 (from docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray])
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 32.4 MB/s eta 0:00:00
# Collecting types-requests>=2.28.11.6 (from docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray])
#   Using cached types_requests-2.31.0.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: hnswlib>=0.6.2 in /home/jupyter/.local/lib/python3.9/site-packages (from docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray]) (0.7.0)
# Requirement already satisfied: protobuf>=3.19.0 in /home/jupyter/.local/lib/python3.9/site-packages (from docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray]) (4.23.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/envs/python39/lib/python3.9/site-packages (from pydantic<2,>=1->langchain[docarray]) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyter/.local/lib/python3.9/site-packages (from requests<3,>=2->langchain[docarray]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter/.local/lib/python3.9/site-packages (from requests<3,>=2->langchain[docarray]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter/.local/lib/python3.9/site-packages (from requests<3,>=2->langchain[docarray]) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in /home/jupyter/.local/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain[docarray]) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/envs/python39/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (23.1)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.1.0->docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/python39/lib/python3.9/site-packages (from rich>=13.1.0->docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray]) (2.15.1)
# Collecting types-urllib3 (from types-requests>=2.28.11.6->docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray])
#   Using cached types_urllib3-1.26.25.13-py3-none-any.whl (15 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/jupyter/.local/lib/python3.9/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain[docarray]) (1.0.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.1.0->docarray[hnswlib]<0.33.0,>=0.32.0->langchain[docarray])
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: types-urllib3, types-requests, orjson, mdurl, markdown-it-py, rich, docarray
# Successfully installed docarray-0.32.1 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.9.1 rich-13.4.2 types-requests-2.31.0.1 types-urllib3-1.26.25.13

# %%
file = 'OutdoorClothingCatalog_1000.csv'
loader = CSVLoader(file_path=file)

# %%
embedding = VertexAIEmbeddings()
index = VectorstoreIndexCreator(
    embedding=embedding,
    vectorstore_cls=DocArrayInMemorySearch
).from_loaders([loader])
